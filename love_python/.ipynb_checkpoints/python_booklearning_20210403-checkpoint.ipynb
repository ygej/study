# %% [markdown]
# # 책과 코드 읽기: 파이썬 머신러닝 완벽가이드
#  - 판다스2 61~86p
#  - DS School 교육자료 참조

# %% [markdown]
# ### 테스트 데이터 준비

# %%
# Import library
import pandas as pd
import numpy as np

# Load data
titanic_df = pd.read_csv('D:/data/titanic/train.csv')
print(titanic_df.shape)
titanic_df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ### 1. 데이터 셀렉션 및 필터링

# %% [markdown]
# 판다스 DataFrame은 크게 세 가지 요소로 구성되어 있습니다.
# 1. 데이터의 행(row)을 가져오는 기준인 인덱스(index)
# 2. 데이터의 열을 가져오는 기준인 컬럼(column)
# 3. 데이터의 값을 가져오는 기준인 값(values)
#
# 각각을 ```.index```, ```.columns```, 그리고 ```.values```를 활용해 불러올 수 있습니다.

# %% [markdown]
# #### 1.1 행(row) 가져오기
# 1) DataFrame에서 ```대괄호[]```를 사용합니다.
#
# 2) ```.loc```(locate의 약자)라는 문법을 사용합니다.
#
# 3) 대괄호 안에 ```인덱스(index)```를 넣습니다. 정확히는 인덱스의 명칭을 넣어줍니다!

# %%
# 데이터 타입은 Series 입니다.
print(type(titanic_df.loc[109]))

# titanic_df의 109 인덱스 가져오기
titanic_df.loc[500]
# Out:
# <class 'pandas.core.series.Series'>
# PassengerId                 501
# Survived                      0
# Pclass                        3
# Name           Calic, Mr. Petar
# Sex                        male
# Age                          17
# SibSp                         0
# Parch                         0
# Ticket                   315086
# Fare                     8.6625
# Cabin                       NaN
# Embarked                      S
# Name: 500, dtype: object

# %%
# 여려 개의 행(row) 접근하기
# 대괄호를 '[[]]' 두 번 사용합니다.
# 안쪽 대괄호를 파이썬의 리스트(list)라고 간주합니다.

# 데이터 타입은 DataFrame 입니다.
print(type(titanic_df.loc[[109,720]]))

# titanic_df의 109, 720 인덱스 가져오기
titanic_df.loc[[109,720]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 109          110         1       3                Moran, Miss. Bertha  female
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
#
#      Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 109  NaN      1      0  371110  24.15   NaN        Q
# 720  6.0      0      1  248727  33.00   NaN        S

# %%
# 안쪽 대괄호의 인덱스를 리스트로 지정해도 결과는 같습니다.
my_list = [109,720]

titanic_df.loc[my_list]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 109          110         1       3                Moran, Miss. Bertha  female
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
#
#      Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 109  NaN      1      0  371110  24.15   NaN        Q
# 720  6.0      0      1  248727  33.00   NaN        S

# %% [markdown]
# #### 1.2 열(column) 가져오기
#
# 1) DataFrame에서 ```대괄호[]```를 사용합니다.
#
# 2) 이 대괄호에 ```문자열```을 집어넣으면 문자열에 해당하는 열(column)을 반환합니다.

# %%
# 데이터 타입은 Series 입니다.
print(type(titanic_df['Name']))

# titanic_df의 'Name' 열 가져오기
titanic_df['Name']
# Out:
# <class 'pandas.core.series.Series'>
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# 여려 개의 열(column) 접근하기
# 대괄호를 '[[]]' 두 번 사용합니다.
# 안쪽 대괄호를 파이썬의 리스트(list)라고 간주합니다.

# 데이터 타입은 DataFrame 입니다.
print(type(titanic_df[['Name', 'Age']]))

# titanic_df의 'Name', 'Age' 열 가져오기
titanic_df[['Name', 'Age']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# #### 1.3 행(row), 열(column) 동시에 가져오기
#
# 1) ```.loc[<<index>>][<column>>]``` 으로 행렬을 동시에 가져올 수 있지만 추천하지 않습니다..
#
# 2)  ```.loc[<<index>>, <column>>]``` 을 추천합니다

# %%
# titanic_df의 인덱스 109의 'Name' 가져오기
titanic_df.loc[109, 'Name']
# Out:
# 'Moran, Miss. Bertha'

# %%
# 여러개의 행(row)의 열(column) 가져오기
titanic_df.loc[[109,720], 'Name']
# Out:
# 109                  Moran, Miss. Bertha
# 720    Harper, Miss. Annie Jessie "Nina"
# Name: Name, dtype: object

# %%
# 여러개의 여러개의 열(column)의 행(row) 가져오기
titanic_df.loc[109, ['Name', 'Age']]
# Out:
# Name    Moran, Miss. Bertha
# Age                     NaN
# Name: 109, dtype: object

# %%
# 여러개의 행(row)의 여러개의 열(column) 가져오기
titanic_df.loc[[109,720], ['Name','Age']]
# Out:
#                                   Name  Age
# 109                Moran, Miss. Bertha  NaN
# 720  Harper, Miss. Annie Jessie "Nina"  6.0

# %% [markdown]
# #### 1.4 행(row), 열(column) 순서대로 가져오기
#
# 1) ```.iloc``` 문법을 사용합니다.
#
# 2)  ```대괄호[]``` 안에 가져올 데이터의 순서를 넣습니다.

# %%
# 데이터 타입은 Series 입니다.
print(type(titanic_df.iloc[0]))

# titanic_df의 첫번째(0번째) 행(row) 가져오기
titanic_df.iloc[0]
# Out:
# <class 'pandas.core.series.Series'>
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# titanic_df의 첫번째(0) 행(row)의 세번째(2) 열(column) 가져오기
titanic_df.iloc[0,2]
# Out:
# 3

# %%
# titanic_df의 첫번째(0), 다섯번째(4) 행(row)의 세번째(2), 여섯번째(5) 열(column) 가져오기
titanic_df.iloc[[0,4],[2,5]]
# Out:
#    Pclass   Age
# 0       3  22.0
# 4       3  35.0

# %% [markdown]
# #### 1.5 색인(indexing)
#
# 1) ```비교연산자(=, >, < 등)``` 문법을 사용합니다.

# %%
# titanic_df에 특정 값(Moran, Miss. Bertha)이 존재하는지 여부를 확인할 수 있습니다.
titanic_df[titanic_df["Name"] == "Moran, Miss. Bertha"]
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex  Age  SibSp  \
# 109          110         1       3  Moran, Miss. Bertha  female  NaN      1
#
#      Parch  Ticket   Fare Cabin Embarked
# 109      0  371110  24.15   NaN        Q

# %%
# titanic_df에 특정 값(Moran, Miss. Bertha)외의 값을 확인할 수 있습니다.
titanic_df[titanic_df["Name"] != "Moran, Miss. Bertha"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 정수형, 실수형은은 크고 작음으로 데이터를 색인할 수 있습니다.
titanic_df[titanic_df["Age"] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
# ``&(and) 기호와 |(or) 기호```를 활용하여 특정 조건을 지정하여 색인할 수 있습니다.
titanic_df[(titanic_df["Age"] > 70) & (titanic_df["Pclass"] == 1) ]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S

# %%
# 조건이 복잡해지면 이렇게 여러 개의 조건으로 나눠서 사용할 수 있습니다.
old = titanic_df["Age"] > 70
pclass_1 = titanic_df["Pclass"] == 1

titanic_df[old & pclass_1]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S

# %% [markdown]
# ### 2. 정렬,Aggregation함수, Groupby 적용

# %% [markdown]
# #### 2.1 정렬하기
#
# 1) index로 정렬합니다. ```.sort_index```
#
# 2) column으로 정렬합니다. ```.sort_values```

# %%
# index를 기준으로 정렬하기
# 숫자는 작은 순(0 ~ 9)으로 알파벳은 A부터 Z까지 정렬합니다.
# 대소문자가 섞여있을 경우 대문자가 앞으로, 소문자가 뒤로 옵니다. 
titanic_df.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 정렬 방식을 오름차순(ascending)이 아닌 내림차순(descending)으로 할 경우, ascending 옵션에 False를 주면 됩니다.
titanic_df.sort_index(ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 만일 행(row)이 아닌 열(column)을 정렬하고 싶다면 axis = 1 옵션을 줍니다.
# 이렇게 하면 컬럼(column) 값을 낮은 순으로(숫자면 0 ~ 9, 알파벳은 A ~ Z) 정렬합니다.
titanic_df.sort_index(axis=1)
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# ...

# %%
# 컬럼값을 기준으로 정렬하기
# by 옵션에는 컬럼명이 들어갑니다.
# 이럴 경우 해당 컬럼값이 작은 순(숫자는 0 ~ 9, 알파벳은 A ~Z)으로 정렬합니다.
titanic_df.sort_values(by="Name")
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
# 정렬 방식을 오름차순(ascending)이 아닌 내림차순(descending)으로 할 경우, ascending 옵션에 False를 주면 됩니다.
titanic_df.sort_values(by="Name", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 868          869         0       3            van Melkebeke, Mr. Philemon
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 286          287         1       3                de Mulder, Mr. Theodore
# ..           ...       ...     ...                                    ...
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 308          309         0       2                    Abelson, Mr. Samuel
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 845          846         0       3                    Abbing, Mr. Anthony
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
# 여러 개의 컬럼값을 기준으로 정렬하고 싶다면 by 옵션에 여러 개의 컬럼명을 리스트로 만들어 넣으면 됩니다.
# 1) Name 컬럼값이 낮은 순으로 정렬한 뒤, 2) Age 컬럼값이 낮은 순으로 정렬합니다.
titanic_df.sort_values(by = ["Name", "Age"])
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# #### 2.2 Aggregation 함수
# [자세한 링크](https://medium.com/@kasiarachuta/basic-statistics-in-pandas-dataframe-594208074f85)

# %%
# Age의 평균값(mean)을 구합니다.
mean_age = titanic_df["Age"].mean()
mean_age
# Out:
# 29.69911764705882

# %%
# Age의 최소값(min)을 구합니다.
min_age = titanic_df["Age"].min()
min_age
# Out:
# 0.42

# %% [markdown]
# #### 2.3 Groupby 적용 (Pivot table)
#
# 1) ```.groupby``` 데이터프레임의 특정 컬럼(내지는 컬럼들)을 그룹화 하는 기능입니다.
#
# 2) ```pd.pivot_table``` 엑셀에서 자주 사용하는 pivot table과 거의 유사
#    [자세한 링크](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html)

# %%
# .groupby
titanic_groupby = titanic_df.groupby('Pclass').count()
titanic_groupby
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
# Pclass 별 Fare의 평균(mean)을 구합니다.
titanic_groupby = titanic_df.groupby('Pclass')['Fare'].mean()
titanic_groupby
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Pclass 별 Fare의 최고값(max)과 최소값(min)을 구하기
titanic_groupby = titanic_df.groupby('Pclass')['Fare'].agg([max,min])
titanic_groupby
# Out:
#              max  min
# Pclass
# 1       512.3292  0.0
# 2        73.5000  0.0
# 3        69.5500  0.0

# %%
# pivot_table
# Pclass 별 Fare의 최고값(max)과 최소값(min)을 구하기
pd.pivot_table(titanic_df, index="Pclass", values="Fare")
# Out:
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
# aggfunc은 aggregate function의 약자입니다.
# 여기에 'sum'을 지정하면 평균(mean)이 아닌 누적값(sum)이 나옵니다.
pd.pivot_table(titanic_df, index="Pclass", values="Fare", aggfunc='sum')
# Out:
#               Fare
# Pclass
# 1       18177.4125
# 2        3801.8417
# 3        6714.6951

# %% [markdown]
# #### 결손 데이터 처리하기

# %%
# 결손 데이터 찾기
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 결손 데이터 처리하기 1 - 결손데이터가 있는 값 바꾸기
titanic_df['Age_fill_na'] = titanic_df['Age'].fillna(titanic_df['Age'].mean())
print(titanic_df.shape)
titanic_df[['Age','Age_fill_na']].head()
# Out:
# (891, 13)
#     Age  Age_fill_na
# 0  22.0         22.0
# 1  38.0         38.0
# 2  26.0         26.0
# 3  35.0         35.0
# 4  35.0         35.0

# %%
# 결손 데이터 처리하기 2 - 결손데이터가 있는 행 삭제하기
data_drop_null = titanic_df.dropna(axis=0)
print(data_drop_null.shape)
data_drop_null.head()
# Out:
# (183, 13)
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Age_fill_na
# 1       0  PC 17599  71.2833   C85        C         38.0
# 3       0    113803  53.1000  C123        S         35.0
# 6       0     17463  51.8625   E46        S         54.0
# 10      1   PP 9549  16.7000    G6        S          4.0
# ...

# %% [markdown]
# #### apply lambda 식으로 데이터 가공
#  ```apply```는  반복문(for)과 유사한 방식으로 동작합니다.
# 판다스의 Series에 ```apply```를 사용하고 여기에 함수명을 지정하면, 해당 Series에 들어간 값을 하나하나 가져와 함수를 실행합니다.

# %%
def old(age):
    return age >= 60
titanic_df['Old_age'] = titanic_df['Age_fill_na'].apply(old)

titanic_df[['Old_age','Age_fill_na']].head()
# Out:
#    Old_age  Age_fill_na
# 0    False         22.0
# 1    False         38.0
# 2    False         26.0
# 3    False         35.0
# 4    False         35.0

# %%
# lambad apply
titanic_df['Old_age_lambda'] = titanic_df['Age_fill_na'].apply(lambda age: age >= 60)

titanic_df[['Old_age_lambda','Age_fill_na']].head()
# Out:
#    Old_age_lambda  Age_fill_na
# 0           False         22.0
# 1           False         38.0
# 2           False         26.0
# 3           False         35.0
# 4           False         35.0

# %%
titanic_df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# # 데이터 분석가 in 타이타닉
#
# ---
#
# 여러분들은 타이타닉 호의 데이터 분석가로 취직하게 되었습니다. 세상에나 첫 날부터 일이 참 많네요!

# %% [markdown]
# #### 문제 1. 인덱스 기준으로 501번째, 601번째 승객을 찾아주세요! 급해요!

# %%
# Write your code here!

# %% [markdown]
# #### 문제 2. 꼬마 손님들을 위해 특별 이벤트를 준비하려 합니다. 15세 미만의 손님들을 찾아주세요!

# %%
# Write your code here!

# %% [markdown]
# #### 문제 3. 타이타닉 호 승선권엔 누가 가장 많은 돈을 썼을까요? Fare를 기준으로 내림차순하여 리스트를 정렬해주세요!

# %%
# Write your code here!

# %% [markdown]
# #### 문제 4. Group by or pivot table을 활용하여 Embarked(승선지) 별 승객들의 Fare와 Age의 평균을 구해주세요!

# %%
# Write your code here!

# %% [markdown]
# #### 문제 5. Embarked(승선지)가 확인되지 않는 승객이 있습니다. 총 몇 명인가요?

# %%
# Write your code here!

# %% [markdown]
# #### 문제 6. VIP 고객을 찾으려 합니다. Fare가 100 이상인 승객들을 구분해주는 'VIP' 컬럼을 만들어주세요!

# %%
# Write your code here!
